# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_csv('loan.csv', header=0)
data.head()
# Out:
# C:\Users\VIJEET\AppData\Local\Temp\ipykernel_9980\2106991480.py:5: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv('loan.csv', header=0)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# ### Data from these coloumns have been deleted as it is not contributing much to the ananlysis :-
# (tot_hi_cred_lim',
# 'total_bal_ex_mort',
# 'total_bc_limit',
# 'total_il_high_credit_limit',
# 'mo_sin_old_il_acct',
# 'mo_sin_old_rev_tl_op',
# 'mo_sin_rcnt_rev_tl_op',
# 'mo_sin_rcnt_tl',
# 'mort_acc',
# 'mths_since_recent_bc',
# 'mths_since_recent_bc_dlq',
# 'mths_since_recent_inq',
# 'mths_since_recent_revol_delinq',
# 'num_accts_ever_120_pd',
# 'num_actv_bc_tl',
# 'num_actv_rev_tl',
# 'num_bc_sats',
# 'num_bc_tl',
# 'num_il_tl',
# 'num_op_rev_tl',
# 'num_rev_accts',
# 'num_rev_tl_bal_gt_0',
# 'num_sats',
# 'num_tl_120dpd_2m',
# 'num_tl_30dpd',
# 'num_tl_90g_dpd_24m',
# 'num_tl_op_past_12m',
# 'pct_tl_nvr_dlq',
# 'percent_bc_gt_75',
# 'tot_coll_amt',
# 'tot_cur_bal',
# 'open_acc_6m',
# 'open_il_6m',
# 'open_il_12m',
# 'open_il_24m',
# 'mths_since_rcnt_il',
# 'total_bal_il',
# 'il_util',
# 'open_rv_12m',
# 'open_rv_24m',
# 'max_bal_bc',
# 'all_util',
# 'total_rev_hi_lim',
# 'inq_fi',
# 'total_cu_tl',
# 'inq_last_12m',
# 'acc_open_past_24mths',
# 'avg_cur_bal',
# 'bc_open_to_buy',
# 'bc_util',
# 'annual_inc_joint',
# 'dti_joint',
# 'verification_status_joint',
# 'mths_since_last_major_derog',
# 'emp_title',
# 'issue_d',
# 'pymnt_plan',
# 'url',
# 'desc',
# 'purpose',
# 'title',
# 'zip_code',
# 'addr_state',
# 'earliest_cr_line',
# 'inq_last_6mths',
# 'mths_since_last_record',
# 'revol_util',
# 'initial_list_status',
# 'last_pymnt_d',
# 'last_pymnt_amnt',
# 'next_pymnt_d',
# 'last_credit_pull_d',
# 'collections_12_mths_ex_med',
# 'policy_code',
# 'application_type',
# 'acc_now_delinq',
# 'chargeoff_within_12_mths',
# 'delinq_amnt',
# 'tax_liens',
# 'delinq_2yrs',
# 'open_acc',
# 'pub_rec',
# 'revol_bal',
# 'total_acc',
# 'out_prncp',
# 'out_prncp_inv',
# 'total_pymnt',
# 'total_pymnt_inv',
# 'total_rec_prncp',
# 'total_rec_int',
# 'total_rec_late_fee',
# 'recoveries',
# 'collection_recovery_fee')

# %%
data.drop(['tot_hi_cred_lim',
'total_bal_ex_mort',
'total_bc_limit',
'total_il_high_credit_limit',
'mo_sin_old_il_acct',
'mo_sin_old_rev_tl_op',
'mo_sin_rcnt_rev_tl_op',
'mo_sin_rcnt_tl',
'mort_acc',
'mths_since_recent_bc',
'mths_since_recent_bc_dlq',
'mths_since_recent_inq',
'mths_since_recent_revol_delinq',
'num_accts_ever_120_pd',
'num_actv_bc_tl',
'num_actv_rev_tl',
'num_bc_sats',
'num_bc_tl',
'num_il_tl',
'num_op_rev_tl',
'num_rev_accts',
'num_rev_tl_bal_gt_0',
'num_sats',
'num_tl_120dpd_2m',
'num_tl_30dpd',
'num_tl_90g_dpd_24m',
'num_tl_op_past_12m',
'pct_tl_nvr_dlq',
'percent_bc_gt_75',
'tot_coll_amt',
'tot_cur_bal',
'open_acc_6m',
'open_il_6m',
'open_il_12m',
'open_il_24m',
'mths_since_rcnt_il',
'total_bal_il',
'il_util',
'open_rv_12m',
'open_rv_24m',
'max_bal_bc',
'all_util',
'total_rev_hi_lim',
'inq_fi',
'total_cu_tl',
'inq_last_12m',
'acc_open_past_24mths',
'avg_cur_bal',
'bc_open_to_buy',
'bc_util',
'annual_inc_joint',
'dti_joint',
'verification_status_joint',
'mths_since_last_major_derog',
'emp_title',
'issue_d',
'pymnt_plan',
'url',
'desc',
'purpose',
'title',
'zip_code',
'addr_state',
'earliest_cr_line',
'inq_last_6mths',
'mths_since_last_record',
'revol_util',
'initial_list_status',
'last_pymnt_d',
'last_pymnt_amnt',
'next_pymnt_d',
'last_credit_pull_d',
'collections_12_mths_ex_med',
'policy_code',
'application_type',
'acc_now_delinq',
'chargeoff_within_12_mths',
'delinq_amnt',
'tax_liens',
'delinq_2yrs',
'open_acc',
'pub_rec',
'revol_bal',
'total_acc',
'out_prncp',
'out_prncp_inv',
'total_pymnt',
'total_pymnt_inv',
'total_rec_prncp',
'total_rec_int',
'total_rec_late_fee',
'recoveries',
'collection_recovery_fee'], axis=1,inplace=True)

# %%
data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade emp_length home_ownership  annual_inc  \
# 0   10.65%       162.87     B        B2  10+ years           RENT     24000.0
# 1   15.27%        59.83     C        C4   < 1 year           RENT     30000.0
# 2   15.96%        84.33     C        C5  10+ years           RENT     12252.0
# 3   13.49%       339.31     C        C1  10+ years           RENT     49200.0
# 4   12.69%        67.79     B        B5     1 year           RENT     80000.0
#
# ...

# %% [markdown]
# ##### Describing the data and getting a glims of count , mean,standard dev,min,max,25%,50% and 75% distributiion of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      39717 non-null  int64
#  1   member_id               39717 non-null  int64
#  2   loan_amnt               39717 non-null  int64
#  3   funded_amnt             39717 non-null  int64
#  4   funded_amnt_inv         39717 non-null  float64
#  5   term                    39717 non-null  object
#  6   int_rate                39717 non-null  object
#  7   installment             39717 non-null  float64
#  8   grade                   39717 non-null  object
#  9   sub_grade               39717 non-null  object
#  10  emp_length              38642 non-null  object
#  11  home_ownership          39717 non-null  object
#  12  annual_inc              39717 non-null  float64
#  13  verification_status     39717 non-null  object
# ...

# %%
data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# ### Removing the outliers
# #### ploting the box plot to on the coloumn 'annual_inc' to identify the outliners

# %%
fig = plt.figure(figsize =(10, 25))
plt.boxplot(data['annual_inc'])
plt.title( "This is a graph represent what are the outliners in the column annual_inc",fontsize = 15)
plt.show()

# %%
data.drop(data[data.annual_inc > 1000000].index, inplace=True)

# %%
fig = plt.figure(figsize =(10, 25))
plt.boxplot(data['annual_inc'])
plt.title( "This is a graph represent how the column annual_inc looks like after removing the outliners",fontsize = 15)
plt.show()

# %%
data['annual_inc'].describe()
# Out:
# count     39703.000000
# mean      68320.002643
# std       47420.217763
# min        4000.000000
# 25%       40320.000000
# 50%       59000.000000
# 75%       82109.160000
# max      948000.000000
# Name: annual_inc, dtype: float64

# %% [markdown]
# #### Removing the current loan from the data set

# %%
data[data['loan_status']=='Current'].count()
# Out:
# id                        1140
# member_id                 1140
# loan_amnt                 1140
# funded_amnt               1140
# funded_amnt_inv           1140
# term                      1140
# int_rate                  1140
# installment               1140
# grade                     1140
# sub_grade                 1140
# emp_length                1098
# home_ownership            1140
# annual_inc                1140
# verification_status       1140
# loan_status               1140
# dti                       1140
# mths_since_last_delinq     363
# pub_rec_bankruptcies      1140
# dtype: int64

# %%
data.drop(data[data.loan_status == 'Current'].index, inplace=True)

# %%
data[data['loan_status']=='Current'].count()
# Out:
# id                        0
# member_id                 0
# loan_amnt                 0
# funded_amnt               0
# funded_amnt_inv           0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# emp_length                0
# home_ownership            0
# annual_inc                0
# verification_status       0
# loan_status               0
# dti                       0
# mths_since_last_delinq    0
# pub_rec_bankruptcies      0
# dtype: int64

# %% [markdown]
# #### The correlation between different coloumns of the data

# %%
a=data.corr()
a
# Out:
#                               id  member_id  loan_amnt  funded_amnt  \
# id                      1.000000   0.993534   0.120579     0.131226
# member_id               0.993534   1.000000   0.120357     0.130251
# loan_amnt               0.120579   0.120357   1.000000     0.981804
# funded_amnt             0.131226   0.130251   0.981804     1.000000
# funded_amnt_inv         0.231540   0.241261   0.937949     0.956169
# installment             0.076004   0.070839   0.932298     0.958043
# annual_inc              0.016155   0.016628   0.364988     0.361591
# dti                     0.091432   0.092583   0.062382     0.062087
# mths_since_last_delinq  0.119333   0.125155   0.015438     0.015968
# pub_rec_bankruptcies   -0.008033  -0.007378  -0.035991    -0.037008
#
#                         funded_amnt_inv  installment  annual_inc       dti  \
# id                             0.231540     0.076004    0.016155  0.091432
# ...

# %%
ax = sns.heatmap( a , linewidth = 0.10000 , cmap = 'coolwarm' )
  
plt.title( "This is a graph represent the co relation between the different columns of the \n data set as the color increasing in the chart hence the values are highly corelated", fontsize = 15)
# plt.text(-5, -1, 'This is a graph represent the co relation between the different columns of the \n data set as the color increasing in the chart hence the values are highly corelated', fontsize = 15)
plt.show()

# %%
data['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Univariate analysis
# #### This graph shows the diffrence in between the fully paid loan people and charged off people

# %%
tr0 = [
             data[data["loan_status"]== 'Fully Paid']["loan_status"].value_counts().index.values,
             data[data["loan_status"]== 'Fully Paid']["loan_status"].value_counts().values,
            
]

tr1 = [
             data[data["loan_status"]== 'Charged Off']["loan_status"].value_counts().index.values,
            data[data["loan_status"]== 'Charged Off']["loan_status"].value_counts().values,
            
]
plt.figure(figsize =(10, 10))
plt.bar( tr0[0],tr0[1], 0.4, label = 'Fully Paid')
plt.bar( tr1[0],tr1[1], 0.4, label = 'Charged Off')
plt.legend(["Fully_paid", "Charged_Off"])
plt.xlabel("Loan_status")
plt.ylabel("Count")
plt.title( "This is a graph represent the total count of people that have \n paid the loan fully vs those who got charged off",fontsize = 15)
# plt.text(-1, -1, 'This is a graph represent the total count of people that have \n paid the loan fully vs those who got charged off', fontsize = 20)
plt.show()

# %% [markdown]
# ### Bivariate analysis

# %%
df_Fully_paid=data[data["loan_status"]== 'Fully Paid']["home_ownership"].values.tolist()
df_Charged_Off=data[data["loan_status"]== 'Charged Off']["home_ownership"].values.tolist()

# %%
plt.figure(figsize =(10, 10))
plt.hist(df_Fully_paid,linewidth=10)
plt.hist(df_Charged_Off,linewidth=1)
plt.legend(["Fully_paid", "Charged_Off"])
plt.xlabel("Home_ownership")
plt.ylabel("Loan_status_Count")
plt.title( "This is a graph represent how the diffrent type of renting criteria can be a deriving factor loan payment and charged off ",fontsize = 15)
plt.show()

# %%
df_Fully_paid_emp_length=data[data["loan_status"]== 'Fully Paid']["emp_length"].values.tolist()
df_Charged_Off_emp_length=data[data["loan_status"]== 'Charged Off']["emp_length"].values.tolist()
plt.figure(figsize =(20, 20))
plt.hist(df_Fully_paid_emp_length,linewidth=10)
plt.hist(df_Charged_Off_emp_length,linewidth=1)
plt.legend(["Fully_paid", "Charged_Off"])
plt.xlabel("Emp_length")
plt.ylabel("Loan_status_Count")
plt.title( "This is a graph represent how the employee length is a factor to the contribution of fully payment and charged off ",fontsize = 15)
plt.show()

# %%
df_Fully_paid_annual_inc=data[data["loan_status"]== 'Fully Paid']["annual_inc"].values.tolist()
df_Charged_Off_annual_inc=data[data["loan_status"]== 'Charged Off']["annual_inc"].values.tolist()
plt.figure(figsize =(20, 20))
plt.hist(df_Fully_paid_annual_inc,linewidth=10)
plt.hist(df_Charged_Off_annual_inc,linewidth=1)
plt.legend(["Fully_paid", "Charged_Off"])
plt.xlabel("Annual_inc")
plt.ylabel("Loan_status_number_Count")
plt.title( "This is a graph represent how the annual income can be used a derving factor of laon payment ",fontsize = 15)
plt.show()

# %%
df_Fully_paid_pub_rec_bankruptcies=data[data["loan_status"]== 'Fully Paid']["pub_rec_bankruptcies"].values.tolist()
df_Charged_Off_pub_rec_bankruptcies=data[data["loan_status"]== 'Charged Off']["pub_rec_bankruptcies"].values.tolist()
plt.figure(figsize =(20, 20))
plt.hist(df_Fully_paid_pub_rec_bankruptcies,linewidth=10)
plt.hist(df_Charged_Off_pub_rec_bankruptcies,linewidth=1)
plt.legend(["Fully_paid", "Charged_Off"])
plt.xlabel("Pub_rec_bankruptcies")
plt.ylabel("Loan_status_Count")
plt.title( "This is a graph represent banckrupy is a driving factor for loan payment and charged off ",fontsize = 15)
plt.show()

# %%
plt.figure(figsize =(20, 20))
plt.hist(data["loan_amnt"],linewidth=10)
plt.hist(data["funded_amnt"],linewidth=1)
plt.legend(["loan_amnt", "funded_amnt"])
plt.xlabel("Amount")
plt.ylabel("Count of People")
plt.title( "This is a graph represent number of people applied for the perticular loan amonut and how much have been approved by the approver",fontsize = 15)
plt.show()

# %%
plt.figure(figsize =(20, 20))
plt.hist(data["funded_amnt"],linewidth=10)
plt.hist(data["funded_amnt_inv"],linewidth=1)
plt.legend(["funded_amnt", "funded_amnt_inv"])
plt.xlabel("Amount")
plt.ylabel("Count of People")
plt.title( "This is a graph represent total number of people got approved by the approver and how much have been actually given by the investers",fontsize = 15)
plt.show()

# %%
plt.figure(figsize =(20, 20))
plt.hist(data["loan_amnt"],linewidth=10)
plt.hist(data["funded_amnt_inv"],linewidth=1)
plt.legend(["loan_amnt", "funded_amnt_inv"])
plt.xlabel("Amount")
plt.ylabel("Count of People")
plt.title( "This is a graph represent total number of people applied for the loan amonut and how much have been actually given by the investers",fontsize = 15)
plt.show()
